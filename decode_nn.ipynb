# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
def make_imports():
    global files, os, PyDrive, GoogleAuth, GoogleDrive, auth, GoogleCredentials, tf, np, projector, TensorBoardColab, hub
    global cv2, contrib_audio, io_ops, datetime, plt, time, pprint, math, scipy, MagicMock, patch, ABCMeta, abstractmethod
    from google.colab import files
    import os
    # !pip install -U -q PyDrive
    from pydrive.auth import GoogleAuth
    from pydrive.drive import GoogleDrive
    from google.colab import auth
    from oauth2client.client import GoogleCredentials

    import tensorflow as tf
    import numpy as np

    from tensorflow.contrib.tensorboard.plugins import projector
    
    # !pip install tensorboardcolab
    from tensorboardcolab import TensorBoardColab
    
    import cv2
    import numpy as np
    
    import tensorflow_hub as hub
    
    from tensorflow.contrib.framework.python.ops import audio_ops as contrib_audio
    from tensorflow.python.ops import io_ops
    
    # !apt install ffmpeg
    
    import datetime
    
    import matplotlib.pyplot as plt
    
    import time
    
    import pprint
    
    import math
    
    import scipy
    
    from unittest.mock import MagicMock, patch
    
    from abc import ABCMeta, abstractmethod # Required to create an abstract class

    
def _authenticate_google():
    auth.authenticate_user()
    gauth = GoogleAuth()
    gauth.credentials = GoogleCredentials.get_application_default()
    global drive
    drive = GoogleDrive(gauth)

def download_files_from_drive(file_ids):    
    for id in file_ids:
        fileId = drive.CreateFile({'id': id}) #DRIVE_FILE_ID is file id example: 1iytA1n2z4go3uVCwE_vIKouTKyIDjEq
        print("Downloading " + fileId['title'])
        fileId.GetContentFile(fileId['title'])  # Save Drive file as a local file
        
def init_tpu_session():
    if 'COLAB_TPU_ADDR' not in os.environ:
        print('ERROR: Not connected to a TPU runtime')
    else:
        global tpu_address
        tpu_address = 'grpc://' + os.environ['COLAB_TPU_ADDR']
        print ('TPU address is', tpu_address)

# %%
make_imports()
_authenticate_google()

project_id = 'cs229-242311'
# !gcloud config set project {project_id}

# Make a unique bucket to which we'll upload the file.
# (GCS buckets are part of a single global namespace.)

# Full reference: https://cloud.google.com/storage/docs/gsutil/commands/mb
# !gsutil -m cp -r gs://transformer-229/model_files_lstm_attention_mod 'gdrive/My Drive'
# Out:
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.
# Updated property [core/project].
# Copying gs://transformer-229/model_files_lstm_attention_mod/hparams.json...
# Copying gs://transformer-229/model_files_lstm_attention_mod/events.out.tfevents.1560339214.89de40a60216...
# Copying gs://transformer-229/model_files_lstm_attention_mod/events.out.tfevents.1560368263.philhoovestol...
# Copying gs://transformer-229/model_files_lstm_attention_mod/checkpoint...
# Copying gs://transformer-229/model_files_lstm_attention_mod/flags.txt...
# Copying gs://transformer-229/model_files_lstm_attention_mod/eval/events.out.tfevents.1560339684.89de40a60216...
# ...

# %%
import os

#only change from here
model ='lstm_seq2seq_attention'
model_dir = 'model_files_lstm_attention_mod'
os.environ['HPARAMS']='lstm_attention'
dec_dir_dir = 'mod'
os.environ['DEC_DIR']='lstm_attention'
#to here

os.environ['DEC_TO']=os.path.join(dec_dir_dir, os.environ['DEC_DIR'])

# %%
#os.chdir('gdrive/My Drive/decodes/'+os.environ['DEC_DIR'])
os.chdir('/content/gdrive/My Drive/')
# !mkdir decodes
os.chdir('decodes')
# !mkdir $DEC_DIR
os.chdir('/content')
# !ls
# Out:
# decode_data  gdrive  sample_data

# %%
# !pip install -U tensor2tensor
# Out:
# Requirement already up-to-date: tensor2tensor in /usr/local/lib/python3.6/dist-packages (1.13.4)
# ...

# %%
# !t2t-decoder --model=$MODEL --hparams_set=$HPARAMS --problem=algorithmic_math_deepmind_all --data_dir="gdrive/My Drive/decode_data/interpolate_algebra__polynomial_roots_data" --output_dir='gdrive/My Drive/'$MODEL_DIR --decode_to_file='gdrive/My Drive/decodes/'$DEC_TO'/algebra__polynomial_roots' --schedule=evaluate --eval_run_autoregressive 
# !t2t-decoder --model=$MODEL --hparams_set=$HPARAMS --problem=algorithmic_math_deepmind_all --data_dir="gdrive/My Drive/decode_data/interpolate_arithmetic__mixed_data" --output_dir='gdrive/My Drive/'$MODEL_DIR --decode_to_file='gdrive/My Drive/decodes/'$DEC_TO'/arithmetic__mixed' --schedule=evaluate --eval_run_autoregressive 
# !t2t-decoder --model=$MODEL --hparams_set=$HPARAMS --problem=algorithmic_math_deepmind_all --data_dir='gdrive/My Drive/decode_data/interpolate_numbers__div_remainder_data' --output_dir='gdrive/My Drive/'$MODEL_DIR --decode_to_file='gdrive/My Drive/decodes/'$DEC_TO'/numbers__div_remainder' --schedule=evaluate --eval_run_autoregressive 
# !t2t-decoder --model=$MODEL --hparams_set=$HPARAMS --problem=algorithmic_math_deepmind_all --data_dir='gdrive/My Drive/decode_data/interpolate_polynomials__evaluate_data' --output_dir='gdrive/My Drive/'$MODEL_DIR --decode_to_file='gdrive/My Drive/decodes/'$DEC_TO'/polynomials__evaluate' --schedule=evaluate --eval_run_autoregressive 
# !t2t-decoder --model=$MODEL --hparams_set=$HPARAMS --problem=algorithmic_math_deepmind_all --data_dir='gdrive/My Drive/decode_data/interpolate_polynomials__simplify_power_data' --output_dir='gdrive/My Drive/'$MODEL_DIR --decode_to_file='gdrive/My Drive/decodes/'$DEC_TO'/polynomials__simplify_power' --schedule=evaluate --eval_run_autoregressive 
# !t2t-decoder --model=$MODEL --hparams_set=$HPARAMS --problem=algorithmic_math_deepmind_all --data_dir='gdrive/My Drive/decode_data/interpolate_data' --output_dir='gdrive/My Drive/'$MODEL_DIR --decode_to_file='gdrive/My Drive/decodes/'$DEC_TO'/interpolate' --schedule=evaluate --eval_run_autoregressive 
# !t2t-decoder --model=$MODEL --hparams_set=$HPARAMS --problem=algorithmic_math_deepmind_all --data_dir='gdrive/My Drive/decode_data/extrapolate_data' --output_dir='gdrive/My Drive/'$MODEL_DIR --decode_to_file='gdrive/My Drive/decodes/'$DEC_TO'/extrapolate' --schedule=evaluate --eval_run_autoregressive
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensor2tensor/utils/trainer_lib.py:240: RunConfig.__init__ (from tensorflow.contrib.learn.python.learn.estimators.run_config) is deprecated and will be removed in a future version.
# Instructions for updating:
# When switching to tf.estimator.Estimator, use tf.estimator.RunConfig instead.
# INFO:tensorflow:Configuring DataParallelism to replicate the model.
# INFO:tensorflow:schedule=evaluate
# INFO:tensorflow:worker_gpu=1
# INFO:tensorflow:sync=False
# WARNING:tensorflow:Schedule=evaluate. Assuming that training is running on a single machine.
# INFO:tensorflow:datashard_devices: ['gpu:0']
# ...
