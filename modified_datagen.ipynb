# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !rm -r 'gdrive/My Drive/modified_preprocessed_dataset_full'

# %%
# !t2t-datagen --tmp_dir='gdrive/My Drive/modified_dataset_full' --data_dir='gdrive/My Drive/modified_preprocessed_dataset_full' --problem=algorithmic_math_deepmind_custom --t2t_usr_dir='gdrive/My Drive/usr_dir'
# Out:
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# INFO:tensorflow:Importing user module usr_dir from path /content/gdrive/My Drive
# INFO:tensorflow:Generating problems:
#     algorithmic:
#       * algorithmic_math_deepmind_custom
# INFO:tensorflow:Generating data for algorithmic_math_deepmind_custom.
# :::MLPv0.5.0 transformer 1560322211.174798965 (/usr/local/lib/python2.7/dist-packages/tensor2tensor/data_generators/text_problems.py:306) preproc_tokenize_training
# INFO:tensorflow:Generating case 0.
# INFO:tensorflow:Generating case 100000.
# INFO:tensorflow:Generating case 200000.
# INFO:tensorflow:Generating case 300000.
# INFO:tensorflow:Generating case 400000.
# INFO:tensorflow:Generating case 500000.
# ...

# %%
def make_imports():
    global files, os, PyDrive, GoogleAuth, GoogleDrive, auth, GoogleCredentials, tf, np, projector, TensorBoardColab, hub
    global cv2, contrib_audio, io_ops, datetime, plt, time, pprint, math, scipy, MagicMock, patch, ABCMeta, abstractmethod
    from google.colab import files
    import os
    # !pip install -U -q PyDrive
    from pydrive.auth import GoogleAuth
    from pydrive.drive import GoogleDrive
    from google.colab import auth
    from oauth2client.client import GoogleCredentials

    import tensorflow as tf
    import numpy as np

    from tensorflow.contrib.tensorboard.plugins import projector
    
    # !pip install tensorboardcolab
    from tensorboardcolab import TensorBoardColab
    
    import cv2
    import numpy as np
    
    import tensorflow_hub as hub
    
    from tensorflow.contrib.framework.python.ops import audio_ops as contrib_audio
    from tensorflow.python.ops import io_ops
    
    # !apt install ffmpeg
    
    import datetime
    
    import matplotlib.pyplot as plt
    
    import time
    
    import pprint
    
    import math
    
    import scipy
    
    from unittest.mock import MagicMock, patch
    
    from abc import ABCMeta, abstractmethod # Required to create an abstract class

    
def _authenticate_google():
    auth.authenticate_user()
    gauth = GoogleAuth()
    gauth.credentials = GoogleCredentials.get_application_default()
    global drive
    drive = GoogleDrive(gauth)

# %%
from google.colab import files
import os

directory =  'gdrive/My Drive/modified_preprocessed_dataset_full'
for file in os.listdir(directory):
  files.download(os.path.join(directory, file))
# Out:
#      |████████████████████████████████| 993kB 2.9MB/s
# ...
# Using TensorFlow backend.
# WARNING: Logging before flag parsing goes to stderr.
# W0612 10:29:16.220599 140593634686848 __init__.py:56] Some hub symbols are not available because TensorFlow version is less than 1.14
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-21-53d4befff781> in <module>()
#       6 directory =  'gdrive/My Drive/modified_preprocessed_dataset_full'
#       7 for file in os.listdir(directory):
# ...

# %%
make_imports()
_authenticate_google()

project_id = 'cs229-242311'
# !gcloud config set project {project_id}

# Make a unique bucket to which we'll upload the file.
# (GCS buckets are part of a single global namespace.)

# Full reference: https://cloud.google.com/storage/docs/gsutil/commands/mb
# !gsutil -m cp -r 'gdrive/My Drive/modified_preprocessed_dataset_full' gs://transformer-229/modified_preprocessed_dataset_full
# Out:
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.6-0ubuntu0.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.
# Updated property [core/project].
# Copying file://gdrive/My Drive/modified_preprocessed_dataset_full/algorithmic_math_deepmind_custom-train-00001-of-00128 [Content-Type=application/octet-stream]...
# Copying file://gdrive/My Drive/modified_preprocessed_dataset_full/algorithmic_math_deepmind_custom-train-00002-of-00128 [Content-Type=application/octet-stream]...
# Copying file://gdrive/My Drive/modified_preprocessed_dataset_full/algorithmic_math_deepmind_custom-train-00004-of-00128 [Content-Type=application/octet-stream]...
# ...
